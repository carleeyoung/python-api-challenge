# %%
import io
import pandas as pd
#from numpy.random import randn

file_path = "../output_data/weather.csv"

df = pd.read_csv(file_path)



str_io = io.StringIO()

df.to_html(buf=str_io, classes='table table-striped')

html_str = str_io.getvalue()

print(html_str)
# Out:
# <table border="1" class="dataframe table table-striped">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City</th>
#       <th>Latitude</th>
#       <th>Longitude</th>
#       <th>Max Temperature</th>
#       <th>Humidity</th>
#       <th>Cloudiness</th>
#       <th>Wind Speed</th>
#       <th>Country</th>
#       <th>DateTime</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Sola</td>
#       <td>-13.88</td>
#       <td>167.55</td>
#       <td>81.21</td>
#       <td>84.0</td>
#       <td>99.0</td>
#       <td>19.51</td>
#       <td>VU</td>
#       <td>1.591198e+09</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Limoges</td>
#       <td>45.75</td>
#       <td>1.33</td>
#       <td>68.00</td>
#       <td>72.0</td>
#       <td>33.0</td>
#       <td>8.05</td>
#       <td>FR</td>
#       <td>1.591198e+09</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Cidreira</td>
#       <td>-30.18</td>
# ...
